# %%
# To do
"""
- Updated the training pixels, so have to check if total sizes are similar, aggregate and create points
- See if more complicated architecture can improve results
- Test if other image with same model gives us similar results
"""

# %%
import ee
import folium
import geehydro
import time
import geopandas as gpd
from pyrsgis import raster
from osgeo import gdal, osr
from pyrsgis.convert import changeDimension
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
from sklearn.metrics import confusion_matrix, precision_score, recall_score

# %%
# initialize the connection to the server
ee.Initialize()

# %%
# Query landast archive
aoi = ee.Geometry.Rectangle([14.35, 26.96, 14.50, 27.11])
col84 = ee.ImageCollection('LANDSAT/LT05/C01/T1_SR').filterDate('1984-04-25', '1984-06-30').filterBounds(aoi)
col93 = ee.ImageCollection('LANDSAT/LT05/C01/T1_SR').filterDate('1993-03-20', '1993-04-30').filterBounds(aoi)
col02 = ee.ImageCollection('LANDSAT/LT05/C01/T1_SR').filterDate('2002-03-11', '2002-03-30').filterBounds(aoi)
col11 = ee.ImageCollection('LANDSAT/LT05/C01/T1_SR').filterDate('2011-03-20', '2011-3-30').filterBounds(aoi)

im84 = col84.sort('SENSING_TIME').first().clip(aoi).select(ee.List.sequence(0,6))
im93 = col93.sort('SENSING_TIME').first().clip(aoi).select(ee.List.sequence(0,6))
im02 = col02.sort('SENSING_TIME').first().clip(aoi).select(ee.List.sequence(0,6))
im11 = col11.sort('SENSING_TIME').first().clip(aoi).select(ee.List.sequence(0,6))

# to get more info: collection.getInfo()

# %%
# Visualize landsat imagery
vizParams = {
  'bands': ['B3', 'B2', 'B1'],
  'min': 0,
  'max': 5000,
  'gamma': [0.95, 1.1, 1]}


# map of Sebha, Libya
sebhaMap = folium.Map(location=[27.039464, 14.426416], zoom_start=14)
sebhaMap.addLayer(im11,vizParams, '2011')
sebhaMap.addLayer(im02,vizParams, '2002')
sebhaMap.addLayer(im93,vizParams, '1993')
sebhaMap.addLayer(im84,vizParams, '1984')

sebhaMap.setControlVisibility(layerControl=True, fullscreenControl=True, latLngPopup=True)
sebhaMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
"""# Export imagery function needs some love

task_config = {
    'scale': 30,  
    'region': aoi,
    'fileFormat': 'GeoTIFF',
    'crs': 4326
    }

def exportImagery(image, name, config):
    task = ee.batch.Export.image(image, name, config)
    task.start()

exportImagery(im84, 'landsat5_1984', task_config)"""
# Out:
# "# Export imagery function needs some love\n\ntask_config = {\n    'scale': 30,  \n    'region': aoi,\n    'fileFormat': 'GeoTIFF',\n    'crs': 4326\n    }\n\ndef exportImagery(image, name, config):\n    task = ee.batch.Export.image(image, name, config)\n    task.start()\n\nexportImagery(im84, 'landsat5_1984', task_config)"

# %%
# Export the image, specifying scale and region.
task = ee.batch.Export.image.toDrive(**{
    'image': im11,
    'description': 'Landsat 5 2011',
    'folder':'UrbanGrowth',
    'scale': 30,
    'fileFormat': 'GeoTIFF'
})
task.start()

while task.active():
  print('Polling for task (id: {}).'.format(task.id))
  print('Task metadata: {})'.format(task.status()))
  time.sleep(5)
# Out:
# Polling for task (id: IKRBQYWLOHW57QNYL56FSAT3).
# Task metadata: {'state': 'READY', 'description': 'Landsat 5 2011', 'creation_timestamp_ms': 1594804913490, 'update_timestamp_ms': 1594804913490, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'IKRBQYWLOHW57QNYL56FSAT3', 'name': 'projects/earthengine-legacy/operations/IKRBQYWLOHW57QNYL56FSAT3'})
# Polling for task (id: IKRBQYWLOHW57QNYL56FSAT3).
# Task metadata: {'state': 'READY', 'description': 'Landsat 5 2011', 'creation_timestamp_ms': 1594804913490, 'update_timestamp_ms': 1594804913490, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'IKRBQYWLOHW57QNYL56FSAT3', 'name': 'projects/earthengine-legacy/operations/IKRBQYWLOHW57QNYL56FSAT3'})
# Polling for task (id: IKRBQYWLOHW57QNYL56FSAT3).
# Task metadata: {'state': 'READY', 'description': 'Landsat 5 2011', 'creation_timestamp_ms': 1594804913490, 'update_timestamp_ms': 1594804913490, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_IMAGE', 'id': 'IKRBQYWLOHW57QNYL56FSAT3', 'name': 'projects/earthengine-legacy/operations/IKRBQYWLOHW57QNYL56FSAT3'})
# Polling for task (id: IKRBQYWLOHW57QNYL56FSAT3).
# Task metadata: {'state': 'RUNNING', 'description': 'Landsat 5 2011', 'creation_timestamp_ms': 1594804913490, 'update_timestamp_ms': 1594804926884, 'start_timestamp_ms': 1594804926748, 'task_type': 'EXPORT_IMAGE', 'id': 'IKRBQYWLOHW57QNYL56FSAT3', 'name': 'projects/earthengine-legacy/operations/IKRBQYWLOHW57QNYL56FSAT3'})

# %%
# Read satellite images from google drive??
# Out:
# {'init': 'epsg:3857'}

# %%
# Read Landsat 5 image
# Read input image
image = r'C:\Users\jneuj\Dropbox\6. GIS\GeoData\SatelliteImagery\Sebha_Landsat5\Landsat 5 2002.tif'
ds1, arr = raster.read(image, bands='all')


# Get metadata of source geotiff for georeferencing for Tiff export
orig = gdal.Open(image)
gT = orig.GetGeoTransform()
proj = orig.GetProjection()

# epsg sat image was 7030 and training data is in 3857

# Check shape of sat image
initShape = arr.shape
print("Initial multispectral image shape: ", initShape)

# Reshape the image to have heigh*width rows and 2 cols (2 bands in the image and 2 input nodes)
arr = changeDimension(arr)
nBands = arr.shape[1]
print("Output multispectral image shape: ", arr.shape)

# Normalize original image
norm2 = np.amax(arr, axis=0)
arr = (arr/(norm2))
# Out:
# Initial multispectral image shape:  (7, 558, 500)
# Output multispectral image shape:  (279000, 7)

# %%
print(proj)
# Out:
# PROJCS["WGS 84 / UTM zone 33N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",15],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32633"]]

# %%
# Read and prep training and validation dataset

# Read ground truth
fp = r"C:\Users\jneuj\Dropbox\6. GIS\GeoData\UrbanGrowth\train2010_pointsgood2.shp"
map_df = gpd.read_file(fp)
print(map_df.crs)

# Setup training data and validation data
xtrain = map_df[['b1_Landsat', 'b2_Landsat', 'b3_Landsat', 'b4_Landsat', 'b5_Landsat', 'b6_Landsat', 'b7_Landsat']]
ytrain = map_df[['classvalue']]

# Normalize training data
norm1 = xtrain.max()
xtrain = (xtrain/(norm1.tolist()))
# Out:
# {'init': 'epsg:3857'}

# %%
print(map_df.crs)
# Out:
# {'init': 'epsg:3857'}

# %%
# Plot training samples on sat image
# Visualize landsat imagery
vizParams = {
  'bands': ['B3', 'B2', 'B1'],
  'min': 0,
  'max': 5000,
  'gamma': [0.95, 1.1, 1]}


# map of Sebha, Libya
sebhaMap = folium.Map(location=[27.039464, 14.426416], zoom_start=14, tiles='Stamen toner')
#sebhaMap.addLayer(im11,vizParams, '2011')
sebhaMap.addLayer(im02,vizParams, '2002')
#sebhaMap.addLayer(im93,vizParams, '1993')
#sebhaMap.addLayer(im84,vizParams, '1984')


# Convert geodf to json
gjson = map_df.to_crs(epsg='4326').to_json()
points = folium.features.GeoJson(gjson)
sebhaMap.add_children(points)
    
sebhaMap.setControlVisibility(layerControl=True, fullscreenControl=True, latLngPopup=True)
sebhaMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Turn the labels into an array
y = np.ravel(ytrain)
x_train, x_test, y_train, y_test = train_test_split(xtrain, y, test_size=0.30, random_state=42)

# Change data format from pandas dataframe to numpy array
x_train = x_train.to_numpy()
x_test = x_test.to_numpy()

# Reshape the data
x_train = x_train.reshape((x_train.shape[0], 1, x_train.shape[1]))
x_test = x_test.reshape((x_test.shape[0], 1, x_test.shape[1]))
arr = arr.reshape((arr.shape[0], 1, arr.shape[1]))

# %%
# Build an artifical neural network
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units = 12, activation = 'relu', input_shape = (1,nBands)))
#model.add(tf.keras.layers.Dense(units = 12, activation = 'relu'))
model.add(tf.keras.layers.Dropout(0.4))
model.add(tf.keras.layers.Dense(units = 10, activation = 'relu'))
model.add(tf.keras.layers.Dense(units=3, activation='softmax'))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['sparse_categorical_accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1, 12)             96
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 12)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1, 10)             130
# _________________________________________________________________
# dense_2 (Dense)              (None, 1, 3)              33
# =================================================================
# Total params: 259
# Trainable params: 259
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit the model and asses accuracy
model.fit(x_train,y_train,epochs = 70)
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print("Test accuracy: {}".format(test_accuracy))
# Out:
# Train on 719 samples
# Epoch 1/70
# 719/719 [==============================] - 1s 1ms/sample - loss: 1.1238 - sparse_categorical_accuracy: 0.3366
# Epoch 2/70
# 719/719 [==============================] - 0s 50us/sample - loss: 1.0950 - sparse_categorical_accuracy: 0.3964
# Epoch 3/70
# 719/719 [==============================] - 0s 50us/sample - loss: 1.0787 - sparse_categorical_accuracy: 0.4200
# Epoch 4/70
# 719/719 [==============================] - 0s 57us/sample - loss: 1.0637 - sparse_categorical_accuracy: 0.4548
# Epoch 5/70
# 719/719 [==============================] - 0s 51us/sample - loss: 1.0353 - sparse_categorical_accuracy: 0.4868
# Epoch 6/70
# 719/719 [==============================] - 0s 51us/sample - loss: 1.0088 - sparse_categorical_accuracy: 0.5313
# Epoch 7/70
# 719/719 [==============================] - 0s 53us/sample - loss: 1.0081 - sparse_categorical_accuracy: 0.5132
# Epoch 8/70
# 719/719 [==============================] - 0s 54us/sample - loss: 0.9770 - sparse_categorical_accuracy: 0.5661
# Epoch 9/70
# 719/719 [==============================] - 0s 50us/sample - loss: 0.9541 - sparse_categorical_accuracy: 0.5994
# Epoch 10/70
# 719/719 [==============================] - 0s 54us/sample - loss: 0.9311 - sparse_categorical_accuracy: 0.6050
# Epoch 11/70
# 719/719 [==============================] - 0s 47us/sample - loss: 0.9026 - sparse_categorical_accuracy: 0.6412
# Epoch 12/70
# 719/719 [==============================] - 0s 47us/sample - loss: 0.8993 - sparse_categorical_accuracy: 0.6300
# Epoch 13/70
# 719/719 [==============================] - 0s 46us/sample - loss: 0.8600 - sparse_categorical_accuracy: 0.6968
# Epoch 14/70
# 719/719 [==============================] - 0s 46us/sample - loss: 0.8559 - sparse_categorical_accuracy: 0.7038
# Epoch 15/70
# 719/719 [==============================] - 0s 51us/sample - loss: 0.8396 - sparse_categorical_accuracy: 0.7218
# Epoch 16/70
# 719/719 [==============================] - 0s 49us/sample - loss: 0.8144 - sparse_categorical_accuracy: 0.7065
# Epoch 17/70
# 719/719 [==============================] - 0s 49us/sample - loss: 0.8011 - sparse_categorical_accuracy: 0.7218
# Epoch 18/70
# 719/719 [==============================] - 0s 51us/sample - loss: 0.7932 - sparse_categorical_accuracy: 0.7065
# Epoch 19/70
# 719/719 [==============================] - 0s 44us/sample - loss: 0.7806 - sparse_categorical_accuracy: 0.7371
# Epoch 20/70
# 719/719 [==============================] - 0s 49us/sample - loss: 0.7679 - sparse_categorical_accuracy: 0.7316
# Epoch 21/70
# 719/719 [==============================] - 0s 46us/sample - loss: 0.7251 - sparse_categorical_accuracy: 0.7497
# Epoch 22/70
# 719/719 [==============================] - 0s 50us/sample - loss: 0.7176 - sparse_categorical_accuracy: 0.7441
# Epoch 23/70
# 719/719 [==============================] - 0s 47us/sample - loss: 0.6989 - sparse_categorical_accuracy: 0.7497
# Epoch 24/70
# 719/719 [==============================] - 0s 50us/sample - loss: 0.6933 - sparse_categorical_accuracy: 0.7636
# Epoch 25/70
# 719/719 [==============================] - 0s 49us/sample - loss: 0.7013 - sparse_categorical_accuracy: 0.7413
# Epoch 26/70
# 719/719 [==============================] - 0s 47us/sample - loss: 0.6725 - sparse_categorical_accuracy: 0.7719
# Epoch 27/70
# 719/719 [==============================] - 0s 46us/sample - loss: 0.6533 - sparse_categorical_accuracy: 0.7705
# Epoch 28/70
# 719/719 [==============================] - 0s 44us/sample - loss: 0.6366 - sparse_categorical_accuracy: 0.7816
# Epoch 29/70
# 719/719 [==============================] - 0s 47us/sample - loss: 0.6362 - sparse_categorical_accuracy: 0.7733
# Epoch 30/70
# 719/719 [==============================] - 0s 49us/sample - loss: 0.6273 - sparse_categorical_accuracy: 0.7844
# Epoch 31/70
# 719/719 [==============================] - 0s 53us/sample - loss: 0.6019 - sparse_categorical_accuracy: 0.7803
# Epoch 32/70
# 719/719 [==============================] - 0s 49us/sample - loss: 0.5833 - sparse_categorical_accuracy: 0.7997
# Epoch 33/70
# 719/719 [==============================] - 0s 46us/sample - loss: 0.5852 - sparse_categorical_accuracy: 0.7914
# Epoch 34/70
# 719/719 [==============================] - 0s 53us/sample - loss: 0.5690 - sparse_categorical_accuracy: 0.7914
# Epoch 35/70
# 719/719 [==============================] - 0s 46us/sample - loss: 0.5702 - sparse_categorical_accuracy: 0.7886
# Epoch 36/70
# 719/719 [==============================] - 0s 49us/sample - loss: 0.5694 - sparse_categorical_accuracy: 0.8067
# Epoch 37/70
# 719/719 [==============================] - 0s 49us/sample - loss: 0.5354 - sparse_categorical_accuracy: 0.8067
# Epoch 38/70
# 719/719 [==============================] - 0s 46us/sample - loss: 0.5273 - sparse_categorical_accuracy: 0.8401
# Epoch 39/70
# 719/719 [==============================] - 0s 46us/sample - loss: 0.5470 - sparse_categorical_accuracy: 0.8095
# Epoch 40/70
# 719/719 [==============================] - 0s 46us/sample - loss: 0.5450 - sparse_categorical_accuracy: 0.8303
# Epoch 41/70
# 719/719 [==============================] - 0s 50us/sample - loss: 0.5216 - sparse_categorical_accuracy: 0.8220
# Epoch 42/70
# 719/719 [==============================] - 0s 43us/sample - loss: 0.5347 - sparse_categorical_accuracy: 0.8206
# Epoch 43/70
# 719/719 [==============================] - 0s 49us/sample - loss: 0.5014 - sparse_categorical_accuracy: 0.8220
# Epoch 44/70
# 719/719 [==============================] - 0s 46us/sample - loss: 0.5047 - sparse_categorical_accuracy: 0.8359
# Epoch 45/70
# 719/719 [==============================] - 0s 46us/sample - loss: 0.5043 - sparse_categorical_accuracy: 0.8248
# Epoch 46/70
# 719/719 [==============================] - 0s 50us/sample - loss: 0.5007 - sparse_categorical_accuracy: 0.8345
# Epoch 47/70
# 719/719 [==============================] - 0s 49us/sample - loss: 0.5073 - sparse_categorical_accuracy: 0.8373
# Epoch 48/70
# 719/719 [==============================] - ETA: 0s - loss: 0.6247 - sparse_categorical_accuracy: 0.750 - 0s 46us/sample - loss: 0.4841 - sparse_categorical_accuracy: 0.8373
# Epoch 49/70
# 719/719 [==============================] - 0s 49us/sample - loss: 0.4786 - sparse_categorical_accuracy: 0.8345
# Epoch 50/70
# 719/719 [==============================] - 0s 46us/sample - loss: 0.4883 - sparse_categorical_accuracy: 0.8317
# Epoch 51/70
# 719/719 [==============================] - 0s 47us/sample - loss: 0.4840 - sparse_categorical_accuracy: 0.8442
# Epoch 52/70
# 719/719 [==============================] - 0s 50us/sample - loss: 0.4738 - sparse_categorical_accuracy: 0.8442
# Epoch 53/70
# 719/719 [==============================] - 0s 49us/sample - loss: 0.4766 - sparse_categorical_accuracy: 0.8470
# Epoch 54/70
# 719/719 [==============================] - 0s 51us/sample - loss: 0.4549 - sparse_categorical_accuracy: 0.8456
# Epoch 55/70
# 719/719 [==============================] - 0s 54us/sample - loss: 0.4878 - sparse_categorical_accuracy: 0.8303
# Epoch 56/70
# 719/719 [==============================] - 0s 47us/sample - loss: 0.4514 - sparse_categorical_accuracy: 0.8554
# Epoch 57/70
# 719/719 [==============================] - 0s 46us/sample - loss: 0.4581 - sparse_categorical_accuracy: 0.8359
# Epoch 58/70
# 719/719 [==============================] - 0s 47us/sample - loss: 0.4718 - sparse_categorical_accuracy: 0.8331
# Epoch 59/70
# 719/719 [==============================] - 0s 47us/sample - loss: 0.4428 - sparse_categorical_accuracy: 0.8526
# Epoch 60/70
# 719/719 [==============================] - 0s 46us/sample - loss: 0.4451 - sparse_categorical_accuracy: 0.8331
# Epoch 61/70
# 719/719 [==============================] - 0s 43us/sample - loss: 0.4635 - sparse_categorical_accuracy: 0.8248
# Epoch 62/70
# 719/719 [==============================] - 0s 49us/sample - loss: 0.4610 - sparse_categorical_accuracy: 0.8275
# Epoch 63/70
# 719/719 [==============================] - 0s 48us/sample - loss: 0.4463 - sparse_categorical_accuracy: 0.8456
# Epoch 64/70
# 719/719 [==============================] - 0s 45us/sample - loss: 0.4547 - sparse_categorical_accuracy: 0.8289
# Epoch 65/70
# 719/719 [==============================] - 0s 44us/sample - loss: 0.4339 - sparse_categorical_accuracy: 0.8581
# Epoch 66/70
# 719/719 [==============================] - 0s 49us/sample - loss: 0.4288 - sparse_categorical_accuracy: 0.8484
# Epoch 67/70
# 719/719 [==============================] - 0s 47us/sample - loss: 0.4507 - sparse_categorical_accuracy: 0.8609
# Epoch 68/70
# 719/719 [==============================] - 0s 51us/sample - loss: 0.4057 - sparse_categorical_accuracy: 0.8595
# Epoch 69/70
# 719/719 [==============================] - 0s 44us/sample - loss: 0.4422 - sparse_categorical_accuracy: 0.8484
# Epoch 70/70
# 719/719 [==============================] - 0s 47us/sample - loss: 0.4136 - sparse_categorical_accuracy: 0.8554
# 309/1 [========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Test accuracy: 0.909385085105896

# %%
# Model is maybe heavily overfit, but let's keep it for now
model_json = model.to_json()
with open("fashion_model.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights("fashion_model.h5")

# %%
# Create new array with same shape as y_test, but with classified results of predicted output on x_test
yTestPredicted = model.predict(x_test)
y_test_pred = np.empty(y_test.shape)

count = 0
for i in yTestPredicted:
    print(i)
    for j in i:        
        testmax = np.amax(j, axis=-1)
        test = np.where(j == testmax)
        y_test_pred[count] = test[0]
        count += 1
y_test_pred = y_test_pred.astype(np.int)
# Out:
# [[0.06199856 0.929885   0.00811641]]
# [[0.8121313  0.03301644 0.15485229]]
# [[0.07758209 0.9136069  0.00881095]]
# [[3.1454112e-02 8.0867510e-05 9.6846503e-01]]
# [[0.8415435  0.04436481 0.11409172]]
# [[0.15757059 0.7456361  0.0967933 ]]
# [[0.32347617 0.00947609 0.66704774]]
# [[0.43327063 0.03001092 0.5367184 ]]
# [[0.14631909 0.00185995 0.851821  ]]
# [[0.78919405 0.14021719 0.07058874]]
# [[0.23074517 0.72696805 0.04228672]]
# [[0.018723   0.9776277  0.00364925]]
# [[0.04682466 0.92642576 0.02674962]]
# [[0.07444177 0.91398525 0.01157288]]
# [[0.30322576 0.00488428 0.69188994]]
# [[1.9626236e-03 1.2959196e-06 9.9803609e-01]]
# [[0.8169954  0.04952221 0.13348237]]
# [[0.03672063 0.95731044 0.00596897]]
# [[0.06818278 0.9232105  0.00860671]]
# [[0.22701842 0.72550136 0.04748024]]
# [[0.65161175 0.02152553 0.3268627 ]]
# [[0.7660598  0.16426206 0.06967805]]
# [[0.30940259 0.11637253 0.5742249 ]]
# [[0.25573203 0.00254572 0.74172217]]
# [[0.21364032 0.00120536 0.78515434]]
# [[9.715060e-02 7.002188e-04 9.021492e-01]]
# [[0.22873087 0.0037355  0.7675336 ]]
# [[2.7487770e-02 6.0174774e-05 9.7245210e-01]]
# [[0.83453923 0.03593475 0.12952605]]
# [[0.05175359 0.9409865  0.00725977]]
# [[0.14187732 0.00095764 0.85716504]]
# [[5.9925683e-04 8.5516865e-07 9.9939990e-01]]
# [[4.2351432e-02 8.3337232e-05 9.5756519e-01]]
# [[0.17209819 0.00120807 0.8266938 ]]
# [[5.3817482e-04 6.4010908e-07 9.9946123e-01]]
# [[0.77819806 0.03630629 0.18549564]]
# [[0.02203813 0.9738479  0.00411397]]
# [[3.1244667e-02 6.2211395e-05 9.6869308e-01]]
# [[9.233416e-02 4.822187e-04 9.071836e-01]]
# [[0.00502064 0.99352247 0.00145694]]
# [[4.792962e-02 8.948850e-05 9.519809e-01]]
# [[0.01373648 0.9833762  0.00288733]]
# [[1.412966e-01 6.182854e-04 8.580851e-01]]
# [[0.42716148 0.01154512 0.56129336]]
# [[0.4934333 0.0217624 0.4848043]]
# [[0.20678554 0.759941   0.03327348]]
# [[0.07513402 0.91508996 0.00977593]]
# [[0.02438794 0.97107744 0.00453456]]
# [[0.01701649 0.97963834 0.00334506]]
# [[0.18551366 0.7158533  0.09863308]]
# [[0.42725387 0.54181564 0.03093054]]
# [[0.82320696 0.05073392 0.12605907]]
# [[0.83761275 0.03165643 0.13073082]]
# [[0.16525686 0.00196548 0.8327777 ]]
# [[0.61631423 0.2405764  0.14310932]]
# [[0.8031448  0.12643473 0.0704205 ]]
# [[0.03812559 0.9556338  0.00624052]]
# [[0.00966278 0.98809    0.00224732]]
# [[0.74621767 0.1989936  0.05478879]]
# [[0.02378655 0.9718988  0.00431471]]
# [[0.0502902  0.94243276 0.00727703]]
# [[0.7342167  0.2123548  0.05342852]]
# [[0.31809238 0.00507306 0.6768346 ]]
# [[4.4056062e-02 1.6331630e-04 9.5578057e-01]]
# [[0.01610727 0.98066175 0.00323095]]
# [[0.03062358 0.96412617 0.00525026]]
# [[0.01443277 0.9824508  0.00311643]]
# [[0.58446777 0.15326242 0.26226982]]
# [[0.7987389  0.10400695 0.09725422]]
# [[0.02000749 0.9763767  0.00361576]]
# [[0.09061786 0.89865446 0.01072767]]
# [[0.01605863 0.98071194 0.00322938]]
# [[0.01856764 0.97770405 0.00372828]]
# [[0.53288937 0.3124236  0.15468705]]
# [[0.03221083 0.9623154  0.00547381]]
# [[0.00772162 0.9902535  0.00202487]]
# [[0.00854774 0.989273   0.00217926]]
# [[0.8072181  0.02901839 0.16376354]]
# [[0.01582838 0.9810168  0.00315485]]
# [[0.83755755 0.07291967 0.08952284]]
# [[0.01889259 0.9775119  0.00359554]]
# [[0.05018602 0.9423432  0.00747084]]
# [[1.9586880e-03 1.2382570e-06 9.9804014e-01]]
# [[0.81240565 0.02088404 0.16671036]]
# [[0.7708701  0.1686105  0.06051953]]
# [[0.76667565 0.01861442 0.21470995]]
# [[0.5297194  0.04441552 0.42586508]]
# [[0.83100677 0.06634478 0.10264847]]
# [[0.36585197 0.6086888  0.02545923]]
# [[0.8285401  0.07966883 0.09179109]]
# [[0.20325945 0.00406133 0.79267925]]
# [[0.06818278 0.9232105  0.00860671]]
# [[0.03633349 0.9576356  0.00603087]]
# [[0.7894144  0.03299714 0.17758845]]
# [[0.11507477 0.00130632 0.88361895]]
# [[0.83095276 0.0279447  0.14110261]]
# [[0.8233765  0.07560396 0.10101952]]
# [[0.34986308 0.6129554  0.0371815 ]]
# [[0.10738426 0.00111551 0.89150023]]
# [[0.24537063 0.00231237 0.752317  ]]
# [[0.7782331  0.15132228 0.07044468]]
# [[0.06880619 0.9025327  0.02866122]]
# [[0.80123705 0.11323038 0.08553256]]
# [[0.01938565 0.97691035 0.00370403]]
# [[8.4224425e-02 4.0497634e-04 9.1537058e-01]]
# [[0.8148054  0.10774086 0.07745374]]
# [[7.3209159e-02 4.2036545e-04 9.2637050e-01]]
# [[0.80062777 0.04417391 0.15519829]]
# [[0.28102562 0.45025408 0.26872027]]
# [[0.03571188 0.958422   0.00586607]]
# [[1.4796235e-01 5.3399563e-04 8.5150367e-01]]
# [[0.1308997  0.00141269 0.86768764]]
# [[0.05569099 0.93708503 0.00722405]]
# [[0.1223625  0.00257109 0.8750664 ]]
# [[0.02203813 0.9738479  0.00411397]]
# [[0.8383217  0.07046332 0.091215  ]]
# [[0.8402208  0.04790813 0.11187105]]
# [[0.8219452  0.08477163 0.09328324]]
# [[0.6287576  0.2922632  0.07897914]]
# [[0.02440746 0.9711702  0.00442233]]
# [[0.28668112 0.68098706 0.03233183]]
# [[2.8379921e-02 5.7627425e-05 9.7156245e-01]]
# [[0.7140898  0.2351041  0.05080608]]
# [[0.6839861  0.09722082 0.218793  ]]
# [[0.02011559 0.97610044 0.003784  ]]
# [[0.37874752 0.00799321 0.61325926]]
# [[0.06880619 0.9025327  0.02866122]]
# [[0.18348533 0.6699914  0.14652331]]
# [[0.34420013 0.00860777 0.64719206]]
# [[0.02843487 0.96668756 0.00487761]]
# [[0.19811945 0.00099067 0.8008899 ]]
# [[4.1910488e-02 1.3486693e-04 9.5795470e-01]]
# [[0.01953546 0.9767627  0.00370188]]
# [[0.5789368  0.0377003  0.38336286]]
# [[0.67598397 0.01153786 0.31247818]]
# [[0.7663375  0.1745498  0.05911265]]
# [[0.21534503 0.00308383 0.78157115]]
# [[0.8393075  0.07104769 0.08964481]]
# [[0.14035662 0.00100904 0.85863435]]
# [[0.81362927 0.08501448 0.10135622]]
# [[0.8285401  0.07966883 0.09179109]]
# [[0.01867075 0.9777598  0.00356948]]
# [[0.01674263 0.9799273  0.00333013]]
# [[0.785491   0.07037028 0.14413866]]
# [[4.6630416e-02 1.9502161e-04 9.5317453e-01]]
# [[0.8374048  0.05819822 0.10439695]]
# [[0.6488336  0.01602737 0.33513907]]
# [[0.06943321 0.9217108  0.00885597]]
# [[0.02571092 0.96958935 0.0046996 ]]
# [[0.3511877  0.01076699 0.6380454 ]]
# [[0.27704164 0.6982269  0.0247314 ]]
# [[0.33598924 0.18807991 0.47593087]]
# [[0.02409554 0.97132427 0.00458018]]
# [[0.26734605 0.00283679 0.72981715]]
# [[6.7079693e-02 1.7127108e-04 9.3274909e-01]]
# [[5.6908443e-04 5.4326313e-07 9.9943036e-01]]
# [[0.80483913 0.03153919 0.16362166]]
# [[0.00507078 0.99345917 0.0014701 ]]
# [[1.1193338e-01 3.3959214e-04 8.8772708e-01]]
# [[0.7627553  0.01134004 0.22590469]]
# [[0.01247855 0.984783   0.00273847]]
# [[0.01610696 0.9807777  0.00311535]]
# [[0.7484282  0.19744413 0.05412769]]
# [[0.10738426 0.00111551 0.89150023]]
# [[0.82869536 0.07359256 0.09771213]]
# [[0.4999006  0.01554139 0.48455802]]
# [[0.75306594 0.12432703 0.12260699]]
# [[0.37862924 0.00778148 0.6135893 ]]
# [[0.8250102  0.05980948 0.11518028]]
# [[0.77687883 0.03638244 0.18673865]]
# [[0.29122683 0.00409852 0.70467466]]
# [[0.29129508 0.00409816 0.7046067 ]]
# [[1.4429982e-01 5.1578169e-04 8.5518438e-01]]
# [[0.83108205 0.03300129 0.13591662]]
# [[4.1865841e-02 1.5452199e-04 9.5797962e-01]]
# [[0.01444747 0.9825565  0.00299592]]
# [[0.19078204 0.7762659  0.03295206]]
# [[0.03812559 0.9556338  0.00624052]]
# [[6.8467245e-02 4.5311704e-04 9.3107969e-01]]
# [[4.0542047e-02 9.3726914e-05 9.5936424e-01]]
# [[3.6528051e-02 1.0612274e-04 9.6336579e-01]]
# [[0.84510744 0.05520821 0.09968442]]
# [[0.4657219  0.4592455  0.07503259]]
# [[0.18853383 0.00978806 0.80167806]]
# [[0.25379467 0.00482028 0.74138504]]
# [[0.62460124 0.03764561 0.3377532 ]]
# [[0.45042315 0.14116676 0.40841007]]
# [[0.24056365 0.7399207  0.01951567]]
# [[8.3099581e-02 1.7418967e-04 9.1672623e-01]]
# [[4.4570893e-02 2.0891361e-04 9.5522016e-01]]
# [[4.5128278e-02 1.6817426e-04 9.5470357e-01]]
# [[0.03571188 0.958422   0.00586607]]
# [[0.03798917 0.9558397  0.00617119]]
# [[0.6627348  0.06584939 0.27141577]]
# [[5.0924215e-02 1.4991872e-04 9.4892585e-01]]
# [[0.30322576 0.00488428 0.69188994]]
# [[0.16828643 0.00131525 0.8303984 ]]
# [[0.24017833 0.00210679 0.7577149 ]]
# [[0.26878697 0.03741801 0.693795  ]]
# [[0.13469157 0.8455919  0.01971651]]
# [[3.0462746e-02 9.3508832e-05 9.6944368e-01]]
# [[0.08841275 0.9020409  0.00954639]]
# [[0.3297477 0.0011239 0.6691284]]
# [[0.04804443 0.94210476 0.00985079]]
# [[0.00803582 0.98984325 0.00212086]]
# [[0.8285223  0.07006118 0.10141649]]
# [[0.83568984 0.08862039 0.07568969]]
# [[5.6910358e-02 1.0770526e-04 9.4298196e-01]]
# [[0.05095588 0.9419728  0.00707141]]
# [[0.05154742 0.9405756  0.00787704]]
# [[0.7866819  0.13332568 0.07999239]]
# [[0.25683516 0.00345148 0.7397133 ]]
# [[1.5270256e-01 5.0548703e-04 8.4679192e-01]]
# [[0.09146935 0.8974071  0.01112355]]
# [[1.2192491e-01 6.3935260e-04 8.7743568e-01]]
# [[0.22720362 0.00277729 0.7700191 ]]
# [[6.506343e-02 5.051858e-04 9.344314e-01]]
# [[0.7645845  0.02654859 0.20886691]]
# [[0.2849422  0.00617614 0.7088817 ]]
# [[0.29252544 0.00402637 0.7034482 ]]
# [[0.79247797 0.06017236 0.14734966]]
# [[0.3662566  0.02614537 0.60759807]]
# [[0.02469716 0.9708164  0.0044864 ]]
# [[0.80836475 0.12014861 0.07148661]]
# [[0.06874105 0.92270195 0.00855708]]
# [[0.81388235 0.05251783 0.13359982]]
# [[0.7182127  0.17919062 0.10259667]]
# [[1.5270256e-01 5.0548703e-04 8.4679192e-01]]
# [[0.04134234 0.95223594 0.00642183]]
# [[0.8420943  0.03724995 0.12065578]]
# [[0.56766754 0.0321991  0.4001333 ]]
# [[0.018723   0.9776277  0.00364925]]
# [[0.81409365 0.063481   0.12242538]]
# [[0.79763013 0.04935129 0.15301865]]
# [[0.1109354  0.00131749 0.88774705]]
# [[0.83283716 0.06973854 0.09742434]]
# [[1.5270256e-01 5.0548703e-04 8.4679192e-01]]
# [[0.79759854 0.0294014  0.1730001 ]]
# [[0.03118956 0.9635424  0.00526795]]
# [[0.10805225 0.87828416 0.01366363]]
# [[0.03171475 0.9630096  0.00527562]]
# [[0.20583144 0.00415299 0.7900156 ]]
# [[0.03491439 0.95928097 0.0058047 ]]
# [[4.03072871e-02 1.20039265e-04 9.59572613e-01]]
# [[0.565756   0.29414093 0.14010309]]
# [[0.8418797  0.0458634  0.11225691]]
# [[0.16568935 0.00163009 0.8326806 ]]
# [[0.2351952  0.05708344 0.7077213 ]]
# [[0.83241147 0.03665574 0.13093288]]
# [[0.03188172 0.9626934  0.00542487]]
# [[0.69673705 0.04269126 0.26057178]]
# [[0.04069129 0.9528728  0.00643597]]
# [[0.8241497  0.02189429 0.15395597]]
# [[0.34420013 0.00860777 0.64719206]]
# [[0.29648587 0.6613796  0.04213457]]
# [[0.84361124 0.04564748 0.11074133]]
# [[0.0137393  0.9833483  0.00291245]]
# [[1.8078622e-01 5.8249116e-04 8.1863129e-01]]
# [[0.45706344 0.00723609 0.53570044]]
# [[0.2795515  0.00307007 0.71737844]]
# [[0.17679565 0.79004693 0.03315732]]
# [[0.11674938 0.8685014  0.01474918]]
# [[0.00456985 0.99403316 0.00139696]]
# [[0.01610696 0.9807777  0.00311535]]
# [[5.8386789e-04 6.9471577e-07 9.9941540e-01]]
# [[0.04337475 0.9496055  0.00701977]]
# [[0.3918475 0.0073248 0.6008277]]
# [[0.8389615  0.04651727 0.11452123]]
# [[0.19908284 0.00082969 0.80008745]]
# [[0.05696027 0.93526834 0.00777133]]
# [[0.7440827  0.20069042 0.05522697]]
# [[0.01868637 0.97772527 0.00358832]]
# [[0.02448126 0.9708463  0.00467246]]
# [[0.78776205 0.11384569 0.09839218]]
# [[0.5289754  0.00657091 0.46445367]]
# [[0.789992   0.14334612 0.06666193]]
# [[0.06013005 0.9321735  0.00769643]]
# [[3.9221782e-02 5.2457690e-05 9.6072578e-01]]
# [[0.8412112  0.05606926 0.10271954]]
# [[0.84651685 0.04514022 0.10834283]]
# [[0.01220366 0.9850044  0.0027919 ]]
# [[0.78736305 0.09599192 0.116645  ]]
# [[0.01875673 0.9776164  0.00362686]]
# [[0.413048   0.00118599 0.58576596]]
# [[0.22648098 0.6262598  0.14725922]]
# [[6.147879e-04 6.944029e-07 9.993845e-01]]
# [[0.6672822  0.2789303  0.05378743]]
# [[0.72488374 0.21423288 0.06088337]]
# [[0.06880619 0.9025327  0.02866122]]
# [[0.294491   0.00625471 0.69925433]]
# [[0.83928823 0.05934327 0.10136849]]
# [[0.8356266  0.07139318 0.09298027]]
# [[1.3164492e-01 7.0177112e-04 8.6765337e-01]]
# [[0.80799305 0.12144529 0.07056168]]
# [[1.0260548e-01 7.0520950e-04 8.9668930e-01]]
# [[0.15711986 0.81621164 0.02666843]]
# [[0.3809878  0.00930857 0.6097036 ]]
# [[0.6264298  0.09227303 0.28129718]]
# [[1.1125765e-01 4.4818010e-04 8.8829422e-01]]
# [[0.31003702 0.00437717 0.68558574]]
# [[0.0154382  0.9814363  0.00312542]]
# [[0.34986308 0.6129554  0.0371815 ]]
# [[0.3097912  0.00511399 0.68509483]]
# [[0.01939012 0.9767701  0.00383984]]
# [[0.07804859 0.90804166 0.01390975]]
# [[0.8300718  0.07401013 0.09591796]]
# [[0.8269968  0.09309829 0.07990486]]
# [[0.04063156 0.9522579  0.00711055]]
# [[0.7790941  0.15754017 0.0633657 ]]

# %%
cMatrix = confusion_matrix(y_test, y_test_pred)
#pScore = precision_score(y_test, yTestPredicted)
#rScore = recall_score(y_test, yTestPredicted)

print("Confusion matrix: for 14 nodes\n", cMatrix)
#print("\nP-Score: %.3f, R-Score: %.3f" % (pScore, rScore))
# Out:
# Confusion matrix: for 14 nodes
#  [[ 90   3  11]
#  [  4 101   2]
#  [  5   3  90]]

# %%
# Perform classifier on whole image arr
pred = model.predict(arr)
pred.shape
# Out:
# (279000, 1, 3)

# %%
pred0 = pred[:,:,0]  #Why is this different in the article?
pred1 = pred[:,:,1]
pred2 = pred[:,:,2]

# %%
output0 = np.reshape(pred0,  (ds1.RasterYSize, ds1.RasterXSize))
output1 = np.reshape(pred1,  (ds1.RasterYSize, ds1.RasterXSize))
output2 = np.reshape(pred2,  (ds1.RasterYSize, ds1.RasterXSize))
output0.shape
# Out:
# (558, 500)

# %%
outFile0 = r"C:\Users\jneuj\Dropbox\6. GIS\GeoData\UrbanGrowth\output\sebha\2002\builtup.tiff"
raster.export(output0, ds1, filename=outFile0, dtype='float')

outFile1 = r"C:\Users\jneuj\Dropbox\6. GIS\GeoData\UrbanGrowth\output\sebha\2002\vegetation.tiff"
raster.export(output1, ds1, filename=outFile1, dtype='float')

outFile2 = r"C:\Users\jneuj\Dropbox\6. GIS\GeoData\UrbanGrowth\output\sebha\2002\baresoil.tiff"
raster.export(output2, ds1, filename=outFile2, dtype='float')
