# %%
import rasterio
import numpy as np
import datetime
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
import random
import shapely as sl
from shapely.geometry import Point
from shapely.geometry import shape
import shapefile
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import geopandas as gpd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import osgeo
from osgeo import gdal, osr
import os

# %%
# Read images
with rasterio.open(r'C:\Users\jneuj\Dropbox\6. GIS\projects\LC Sebha\newpython\testinput.tif', 'r') as ds:
    arr = ds.read()  # read all raster values

# %%
# Get metadata of source geotiff for georeferencing
orig = gdal.Open(r'C:\Users\jneuj\Dropbox\6. GIS\projects\LC Sebha\newpython\L5_2010_ND45.tif')
gT = orig.GetGeoTransform()
proj = orig.GetProjection()

# %%
initShape = arr.shape
initShape
# Out:
# (2, 631, 533)

# %%
# Reshape the image to have heigh*width rows and 2 cols (2 bands in the image and 2 input nodes)
arr = arr.reshape(arr.shape[1]*arr.shape[2], arr.shape[0])
arr.shape
# Out:
# (336323, 2)

# %%
# Build an artifical neural network
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units = 2, activation = 'relu', input_shape = (2,)))
model.add(tf.keras.layers.Dense(units = 20, activation = 'relu'))
model.add(tf.keras.layers.Dropout(0.4))
model.add(tf.keras.layers.Dense(units = 20, activation = 'relu'))
model.add(tf.keras.layers.Dense(units=2, activation='softmax'))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['sparse_categorical_accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_4 (Dense)              (None, 2)                 6
# _________________________________________________________________
# dense_5 (Dense)              (None, 20)                60
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_7 (Dense)              (None, 2)                 42
# ...
# Total params: 528
# Trainable params: 528
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Read training polygon
fp = r"C:\Users\jneuj\Dropbox\6. GIS\projects\LC Sebha\newpython\training_points_valuegood.shp"
map_df = gpd.read_file(fp)
map_df.head()
minx, miny, maxx, maxy = map_df.total_bounds

ax = map_df.plot(figsize=(40, 40), alpha=0.5, edgecolor='k')
ax.set_ylim(3120000,3140000)
ax.set_xlim(1595000, 1614000)
# Out:
# (1595000, 1614000)

# %%
# Change columns names to make a bit of sense
map_df.columns
map_df = map_df.rename(columns={'RASTERVALU': 'band2'})

# %%
# Try this structure to setup a training data set. Not sure if this will work.
xtrain = map_df[['band1','band2']]
ytrain = map_df[['classvalue']]

# Turn the labels into an array
y = np.ravel(ytrain)
X_train, X_test, y_train, y_test = train_test_split(xtrain, y, test_size=0.30, random_state=42)

# Treat the training data to fit keras input nodes
#scaler = StandardScaler().fit(X_train)
#X_train = scaler.transform(X_train)
#X_test = scaler.transform(X_test)
X_train.shape
# Out:
# (1344, 2)

# %%
# Fit the model and asses accuracy
model.fit(X_train,y_train,epochs = 20)
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test accuracy: {}".format(test_accuracy))
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 1344 samples
# Epoch 1/20
# 1344/1344 [==============================] - 0s 127us/sample - loss: 0.6891 - sparse_categorical_accuracy: 0.5126
# Epoch 2/20
# 1344/1344 [==============================] - 0s 35us/sample - loss: 0.6739 - sparse_categorical_accuracy: 0.5171
# Epoch 3/20
# 1344/1344 [==============================] - 0s 34us/sample - loss: 0.6218 - sparse_categorical_accuracy: 0.6801
# Epoch 4/20
# 1344/1344 [==============================] - 0s 35us/sample - loss: 0.5679 - sparse_categorical_accuracy: 0.7954
# Epoch 5/20
# 1344/1344 [==============================] - 0s 30us/sample - loss: 0.5286 - sparse_categorical_accuracy: 0.8557
# Epoch 6/20
# 1344/1344 [==============================] - 0s 36us/sample - loss: 0.4978 - sparse_categorical_accuracy: 0.8698
# Epoch 7/20
# ...

# %%
# Model is maybe heavily overfit, but let's keep it for now
model_json = model.to_json()
with open("fashion_model.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights("fashion_model.h5")

# %%
pred = model.predict(arr)
pred.shape
# Out:
# (336323, 2)

# %%
test = pred.reshape(2,631,533)
test.shape
# Out:
# (2, 631, 533)

# %%
# -*- coding: utf-8 -*-
def CreateGeoTiff(Name, Array, NDV, 
                  GeoT, proj):
    Array[np.isnan(Array)] = NDV
    driver = gdal.GetDriverByName('GTiff')
    DataSet = driver.Create(Name, Array.shape[2], Array.shape[1], Array.shape[0], gdal.GDT_Float32)
    DataSet.SetGeoTransform(GeoT)
    DataSet.SetProjection(proj )
    for i, image in enumerate(Array, 1):
        DataSet.GetRasterBand(i).WriteArray( image )
        DataSet.GetRasterBand(i).SetNoDataValue(NDV)
    DataSet.FlushCache()
    return Name

os.environ['SHAPE_ENCODING'] = "utf-8"
hope = CreateGeoTiff('testoutput2.tiff', test, -99, gT, proj)

# %%
src = rasterio.open("testoutput2.tiff")
plt.imshow(src.read(2), cmap='viridis')
plt.show()
